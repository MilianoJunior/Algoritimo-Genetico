# %% [markdown]
# ## Algoritmos de otimização
#
# Descrição: A plataforma smarttbot é uma empresa de tecnologia especializada em investimento automatizado na bolsa de valores. Ela possibilita que investidores escolham estratégias que são formadas por indicadores  e configurem parâmetros dos principais indicadores do mercado, existem diversas estratégias, mas o escopo desse projeto vai considerar a tangram. Os parâmetros
# Objetivo: Encontrar os melhores parâmetros da estratégia que retornem um maior lucro.

# %%
#importação das bibliotecas
import time
import random
import math
import pandas as pd
import numpy as np
import chardet

# %%
#¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨
#Serão constantes
ticket = 'WIN'                                     #papel negociado
direction_operations = 'comprado&vendido'          #operações possiveis: compra e venda a descoberto
amount_orders = 1                                  #quantidade de ordens 
start_time = '09:00'                               #horário inicial
end_time = '17:00'                                 #horário limite de operação
#¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨
#Serão variáveis
time_frame = 1                                     #tempo gráfico em min
stop = -200                                        #limite de perda por operação
gain = 200                                         #algo de ganho por operação

# %%
# carregando os dados
with open('M4.csv', 'rb') as f:
    result = chardet.detect(f.read())  # or readline if the file is large

base = pd.read_csv('M4.csv', encoding=result['encoding'],dtype='unicode')

colunas = ['Data','Hora', 'open', 'high', 'low', 'close','VOL']
base = base[colunas][1:200]
base.head()
# Out:
#          Data   Hora      open      high       low     close     VOL
# 1  2014.10.20  09:15  56265.00  56270.00  56250.00  56260.00   65.00
# 2  2014.10.20  09:16  56260.00  56290.00  56250.00  56290.00   80.00
# 3  2014.10.20  09:17  56285.00  56300.00  56270.00  56270.00  124.00
# 4  2014.10.20  09:18  56280.00  56290.00  56270.00  56285.00   25.00
# 5  2014.10.20  09:19  56290.00  56375.00  56290.00  56335.00  237.00

# %%
#Calculando alguns dos indicadores para alteração de parâmetros
class Indicators():
    def __init__(self,name='indicators'):
        self.name = name    
    def sma(self,data,period,column='close'):
        sma_ = pd.Series(data[column].rolling(period).mean(),name ='SMA'+str(period))
        return data.join(sma_)
    def ema(self,data,period,column='close'):
        data['EMA'+str(period)]=data[column].ewm(ignore_na=False,min_periods=period,com=period,adjust=True).mean()
        return data
    def macd(self,data,period_long=26,period_short=12,period_signal=9,column='close'):
        remove_cols = []
        if not 'EMA'+str(period_long) in data.columns:
            data = self.ema(data,period_long)
            remove_cols.append('EMA'+str(period_long))
            
        if not 'EMA'+str(period_short) in data.columns:
            data = self.ema(data, period_short)
            remove_cols.append('EMA' + str(period_short))
    
        data['macd_val'] = data['EMA' + str(period_short)] - data['EMA' + str(period_long)]
        data['macd_signal_line'] = data['macd_val'].ewm(ignore_na=False, min_periods=0, com=period_signal, adjust=True).mean()
        data = data.drop(remove_cols, axis=1)
        return data
    def bands(self,data, trend_periods=20, deviation=2, column='close'):
        data['bol_bands_middle'] = data[column].ewm(ignore_na=False, min_periods=0, com=trend_periods, adjust=True).mean()
        for index, row in data.iterrows():
            s = data[column].iloc[index - trend_periods: index]
            sums = 0
            middle_band = data.at[index, 'bol_bands_middle']
            for e in s:
                #e = float(e)
                #print('verificacao:',e,middle_band,type(e),type(middle_band))
                #print('----------------------')
                sums += np.square(e - middle_band)
            
            std = np.sqrt(sums / trend_periods)
            
            upper_band = middle_band + (deviation * std)
            lower_band = middle_band - (deviation * std)
            
            data.at[index,'bol_bands_upper']= upper_band
            data.at[index,'bol_bands_lower']= lower_band
        return data
    def ifr(self,data,period=14):
        delta = data['close'].diff().dropna()
        u = delta * 0
        d = u.copy()
        u[delta > 0] = delta[delta > 0]
        d[delta < 0] = -delta[delta < 0]
        u = u.ewm(span=period,min_periods=0,adjust=False).mean() #first value is sum of avg gains
        d = d.ewm(span=period,min_periods=0,adjust=False).mean() #first value is sum of avg losses
        data['IFR']=1 - 1 / (1 + u/d)
        return data
    def vwap(self,data):
        vol = data.VOL.values
        price = data.close.values
        data['VWAP'] = (vol*price).cumsum()/vol.cumsum()
        return data

# %%
# Instância do objeto Indicators, calculando os valores dos indicadores
indicators = Indicators()
base1 = base[['open', 'high', 'low', 'close','VOL']].astype(float)
base1 = indicators.sma(base1,3)
base1 = indicators.ema(base1,6)
base1 = indicators.macd(base1,26,12,9)
base1 = indicators.bands(base1,20,2)
base1 = indicators.ifr(base1,14)
base1 = indicators.vwap(base1)
base1 = base1.dropna()
base1.head(10)
# Out:
#        open     high      low    close    VOL          SMA3          EMA6  \
# 26  56080.0  56100.0  56015.0  56020.0  265.0  56065.000000  56126.225254
# 27  56020.0  56060.0  56020.0  56050.0   98.0  56046.666667  56115.163644
# 28  56050.0  56060.0  56030.0  56060.0   60.0  56043.333333  56107.176493
# 29  56055.0  56085.0  56045.0  56055.0   88.0  56055.000000  56099.636427
# 30  56050.0  56060.0  56035.0  56050.0   27.0  56055.000000  56092.475269
# 31  56035.0  56035.0  55995.0  56005.0  306.0  56036.666667  56079.872852
# 32  56005.0  56010.0  55955.0  55990.0  155.0  56015.000000  56066.940682
# 33  55985.0  55995.0  55930.0  55940.0  109.0  55978.333333  56048.693592
# 34  55930.0  56020.0  55930.0  55990.0  262.0  55973.333333  56040.264165
# 35  56005.0  56040.0  55980.0  55995.0  148.0  55975.000000  56033.768378
#
#      macd_val  macd_signal_line  bol_bands_middle  bol_bands_upper  \
# 26 -24.413831        -24.413831      56176.127521     56374.521030
# 27 -26.140895        -25.322812      56167.924204     56357.750978
# 28 -27.264924        -26.039458      56161.025018     56332.402683
# 29 -28.304578        -26.698115      56154.355992     56299.858190
# 30 -29.271206        -27.326449      56147.890747     56284.585017
# 31 -31.384015        -28.192416      56139.163236     56268.836914
# 32 -33.592627        -29.227528      56130.173606     56261.441651
# 33 -36.964306        -30.585971      56118.855552     56263.858365
# 34 -38.252765        -31.837530      56111.276950     56258.495907
# 35 -39.109452        -32.954017      56104.513872     56251.009402
#
#     bol_bands_lower       IFR          VWAP
# 26     55977.734013  0.278147  56182.510740
# 27     55978.097431  0.357465  56179.308261
# 28     55989.647353  0.383518  56177.568651
# 29     56008.853794  0.374752  56175.002379
# 30     56011.196478  0.365122  56174.204492
# 31     56009.489559  0.288211  56162.789903
# 32     55998.905561  0.266611  56157.080580
# 33     55973.852739  0.206956  56152.151042
# 34     55964.057992  0.369688  56143.758396
# 35     55958.018342  0.384267  56139.532630

# %%
# Classe trade, faz as operações e retorna o ganho, assim como dataframe com todas as operações realizadas
class Env_trade():
    comprado = False
    vendido = False
    ficha = 0
    cont = 0
    valor = 0
    contC = 0
    contV = 0
    hora = 0
    Stop = 100
    posicao = 0

    def __init__(self,name='wind'):
        self.name = name
        self.CC = []
        self.VV = []
        self.saida = pd.DataFrame(columns=['tipo','entrada','saida','ganho','inicio','fim','duracao','ganhofinal','acumulado','recompensas'])
        self.rewards = []
        self.atual = 0
        self.result = 0
        self.rec = 0
        
        
    def agente_(self,dados,acao,stop,gain,verbose,forma):
        self.cont += 1    
        self.posicao = 0
        self.result = 0
        
        hora = float(dados[0].split(':')[0])
        if hora >= 17 and self.comprado == False and self.vendido == False:
            return self.CC,self.VV, self.saida,self.ficha,self.comprado,self.vendido,0
        if acao == 0:
            recompensa = 0
        elif acao == 1 and self.comprado == False:
            if self.ficha == 0:
                self.ficha = 1
                self.comprado = True
                self.vendido = False
            else:
                self.ficha = 0
                self.comprado = False
                self.vendido = False
            self.posicao = self.compra(dados[1],dados[0],self.ficha,verbose)
            
        elif acao == 2 and self.vendido == False: 
            if self.ficha == 0:
                self.ficha = 1
                self.vendido = True
                self.comprado = False
            else:
                self.ficha = 0
                self.vendido = False
                self.comprado = False
            self.posicao = self.venda(dados[1],dados[0],self.ficha,verbose)
            
        if self.ficha == 1:
            rec = self.valor -dados[4]
            if self.vendido:
                self.rewards.append(rec)
            else:
                self.rewards.append(-rec)
        if self.comprado or self.vendido:
            self.posicao = self.verifica(dados,gain,stop,verbose)

        recompensa = 0
        if self.rec != 0:
            recompensa = self.rec
            self.rec = 0
            
        
        if forma == 0:
            if self.comprado:
                recompensa = dados[4] - self.valor 
            if self.vendido:
                recompensa = self.valor - dados[4]
        if forma == 1:
            if self.comprado == False and self.vendido == False:
                self.atual = 0
            if self.comprado:
                recompensa = dados[4] - self.valor
                if self.atual == 0:
                    self.atual = recompensa
                else:
                    dif = recompensa - self.atual
                    self.atual = recompensa
                    recompensa = dif
            if self.vendido:
                recompensa = self.valor - dados[4]
                if self.atual == 0:
                    self.atual = recompensa
                else:
                    dif = recompensa - self.atual
                    self.atual = recompensa
                    recompensa = dif
        if forma == 2:
            recompensa = 0
            if self.posicao == 4 or self.posicao == 2:
                recompensa = self.result
        if verbose == 1:
            print('##########################')
            print('Contador: ',self.cont)
            # print('Posicao: ',self.posicao)
            print('Hora: ',dados[0])
            print('Open: ',dados[1])
            print('High: ',dados[2])
            print('Low: ',dados[3])
            print('close: ',dados[4])
            print('acao: ',acao)
            print('stop: ',stop)
            print('gain: ',gain)
            print('Comprado: ',self.comprado)
            print('Vendido: ',self.vendido)
            # print('Ficha: ',self.ficha)
            # print('Compras: ',self.CC)
            # print('Vendas: ',self.VV)
            # print('Qtd: ',self.contC,self.contV)
            print('recompensa: ',recompensa)
            print('##########################')
                
        return self.saida,self.comprado,self.vendido,recompensa
                
    def verifica(self,dados,gain,stop,verbose):
        if self.comprado:
            stopmax = dados[3]-self.valor
            gainmin = dados[2]-self.valor

            if stopmax < stop:
                pontos = self.valor - (-stop)
                self.ficha = 0
                self.vendido = False
                self.comprado = False
                self.rec = stop
                return self.venda(pontos,dados[0],self.ficha,verbose)
                
            if gainmin > gain: 
                pontos = self.valor + gain
                self.ficha = 0
                self.vendido = False
                self.comprado = False
                self.rec = gain
                return self.venda(pontos,dados[0],self.ficha,verbose)
                
            
        if self.vendido:
            stopmax = self.valor - dados[2]
            gainmin = self.valor - dados[3]
            if stopmax < stop:
                pontos = self.valor + (-stop)
                self.ficha = 0
                self.vendido = False
                self.comprado = False
                self.rec = stop
                return self.compra(pontos,dados[0],self.ficha,verbose)
            if gainmin > gain:
                pontos = self.valor - gain
                self.ficha = 0
                self.vendido = False
                self.comprado = False
                self.rec = gain
                return self.compra(pontos,dados[0],self.ficha,verbose)
        return self.posicao

    def imprimi(self,pmax,pmin):
        print('---------------------------')
        print('valor da compra: ',self.valor)
        print('pontuacao máxima: ',pmax)
        print('pontuacao mínima: ',pmin)
        print('---------------------------')
    def recompensa(self,dados):
        return dados
    def compra(self,entrada,hora,ficha,verbose):
        if ficha == 1:
            self.valor = entrada
            self.contC += 1 
            self.hora = hora
            
            if verbose == 1:
                print('        ')
                print('********************')
                print('COMPRA: ',entrada)
                print('********************')
                print('        ')
            return 1
        else:
            if verbose == 1:
                print('        ')
                print('********************')
                print('VENDIDO: ',self.valor)
                print('COMPRA: ',entrada)
                print('Lucro: ',self.valor - entrada)
                print('inicio: ',self.hora,' termino: ',hora)
                print('Duracao: ',self.Duracao(self.hora,hora))
                print('recompensas: ',self.rewards)
                print('********************')
                print('        ')
            self.result = self.valor - entrada
            tempo = self.Duracao(self.hora,hora)
            self.VV.append(self.result)
            self.ficha = 0
            self.saida = self.saida.append({'tipo': 'venda',
                                            'entrada':self.valor,
                                            'saida':entrada,
                                            'ganho': self.result,
                                            'inicio':self.hora,
                                            'fim':hora,
                                            'duracao': tempo,
                                            'ganhofinal': self.result - tempo,
                                            'acumulado': sum(self.saida.ganhofinal),
                                            'recompensas': self.rewards}, ignore_index=True)
            self.rewards = []
            return 2
        # return 1
        
    def venda(self,entrada,hora,ficha,verbose):
        if ficha == 1:
            self.valor = entrada
            self.contV += 1
            self.hora = hora
            
            if verbose == 1:
                print('        ')
                print('********************')
                print('VENDA: ',entrada)
                print('********************')
                print('        ')
            return 3
        else:
            if verbose == 1:
                print('        ')
                print('********************')
                print('COMPRADO: ',self.valor)
                print('VENDA: ',entrada)
                print('LUCRO: ',entrada - self.valor)
                print('inicio: ',self.hora,' termino: ',hora)
                print('Duracao: ',self.Duracao(self.hora,hora))
                print('recompensas: ',self.rewards)
                print('********************')
                print('        ')
            self.result = entrada - self.valor
            tempo = self.Duracao(self.hora,hora)
            self.CC.append(self.result )
            self.ficha = 0
            self.saida = self.saida.append({'tipo': 'compra',
                                            'entrada':self.valor,
                                            'saida':entrada,
                                            'ganho': self.result,
                                            'inicio':self.hora,
                                            'fim':hora,
                                            'duracao': tempo,
                                            'ganhofinal': self.result - tempo,
                                            'acumulado': sum(self.saida.ganhofinal),
                                            'recompensas': self.rewards}, ignore_index=True)
            self.rewards = []
            return 4          
        
    def Duracao(self,base1a,base2a):
        base1 = float(base1a.split(':')[1])
        base2 = float(base2a.split(':')[1])
        base3 = float(base1a.split(':')[0])
        base4 = float(base2a.split(':')[0])
        if base1 > base2:
            tempo = ((60*(base4-base3)) - base1)+ base2
        else:
            tempo = base2 - base1
        if base3 > 17 or base4 > 17 or tempo > 50:
            tempo = 0
        # print((base4-base3),base1,base2,tempo)
        return tempo
    
    def reset(self):
        self.saida = self.saida.drop([i for i in range(len(self.saida))])
        self.ficha = 0
        self.cont = 0
        self.VV = []
        self.CC = []
        self.rewards = []
        self.comprado = False
        self.vendido = False

# %%
trader = Env_trade()
base = base.drop(['Data'],axis=1)
base['open'] = base['open'].astype(float)
base['high'] = base['high'].astype(float)
base['low'] = base['low'].astype(float)
base['close'] = base['close'].astype(float)
#agente(self,dados,acao,stop,gain,verbose=0,forma=0):
for i in range(100):
    action = random.randrange(0,3)
    print('action: ',action)
    result,buy,shell,reward = trader.agente_(base.values[i],action,stop,gain,1,0)
# Out:
# action:  1
#
# ********************
# COMPRA:  56265.0
# ********************
#
# ##########################
# Contador:  1
# Hora:  09:15
# Open:  56265.0
# High:  56270.0
# Low:  56250.0
# close:  56260.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  -5.0
# ##########################
# action:  0
# ##########################
# Contador:  2
# Hora:  09:16
# Open:  56260.0
# High:  56290.0
# Low:  56250.0
# close:  56290.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  25.0
# ##########################
# action:  2
#
# ********************
# COMPRADO:  56265.0
# VENDA:  56285.0
# LUCRO:  20.0
# inicio:  09:15  termino:  09:17
# Duracao:  2.0
# recompensas:  [-5.0, 25.0]
# ********************
#
# ##########################
# Contador:  3
# Hora:  09:17
# Open:  56285.0
# High:  56300.0
# Low:  56270.0
# close:  56270.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  2
#
# ********************
# VENDA:  56280.0
# ********************
#
# ##########################
# Contador:  4
# Hora:  09:18
# Open:  56280.0
# High:  56290.0
# Low:  56270.0
# close:  56285.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  -5.0
# ##########################
# action:  0
# ##########################
# Contador:  5
# Hora:  09:19
# Open:  56290.0
# High:  56375.0
# Low:  56290.0
# close:  56335.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  -55.0
# ##########################
# action:  2
# ##########################
# Contador:  6
# Hora:  09:20
# Open:  56330.0
# High:  56350.0
# Low:  56310.0
# close:  56330.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  -50.0
# ##########################
# action:  0
# ##########################
# Contador:  7
# Hora:  09:21
# Open:  56325.0
# High:  56360.0
# Low:  56325.0
# close:  56350.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  -70.0
# ##########################
# action:  0
# ##########################
# Contador:  8
# Hora:  09:22
# Open:  56360.0
# High:  56380.0
# Low:  56345.0
# close:  56370.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  -90.0
# ##########################
# action:  1
#
# ********************
# VENDIDO:  56280.0
# COMPRA:  56370.0
# Lucro:  -90.0
# inicio:  09:18  termino:  09:23
# Duracao:  5.0
# recompensas:  [-5.0, -55.0, -50.0, -70.0, -90.0]
# ********************
#
# ##########################
# Contador:  9
# Hora:  09:23
# Open:  56370.0
# High:  56375.0
# Low:  56345.0
# close:  56375.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  2
#
# ********************
# VENDA:  56375.0
# ********************
#
# ##########################
# Contador:  10
# Hora:  09:24
# Open:  56375.0
# High:  56375.0
# Low:  56255.0
# close:  56280.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  95.0
# ##########################
# action:  0
# ##########################
# Contador:  11
# Hora:  09:25
# Open:  56275.0
# High:  56300.0
# Low:  56275.0
# close:  56280.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  95.0
# ##########################
# action:  2
# ##########################
# Contador:  12
# Hora:  09:26
# Open:  56280.0
# High:  56285.0
# Low:  56180.0
# close:  56220.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  155.0
# ##########################
# action:  2
#
# ********************
# VENDIDO:  56375.0
# COMPRA:  56175.0
# Lucro:  200.0
# inicio:  09:24  termino:  09:27
# Duracao:  3.0
# recompensas:  [95.0, 95.0, 155.0, 235.0]
# ********************
#
# ##########################
# Contador:  13
# Hora:  09:27
# Open:  56215.0
# High:  56220.0
# Low:  56130.0
# close:  56140.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  200
# ##########################
# action:  1
#
# ********************
# COMPRA:  56140.0
# ********************
#
# ##########################
# Contador:  14
# Hora:  09:28
# Open:  56140.0
# High:  56165.0
# Low:  56135.0
# close:  56165.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  25.0
# ##########################
# action:  0
# ##########################
# Contador:  15
# Hora:  09:29
# Open:  56165.0
# High:  56190.0
# Low:  56160.0
# close:  56175.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  35.0
# ##########################
# action:  1
# ##########################
# Contador:  16
# Hora:  09:30
# Open:  56165.0
# High:  56170.0
# Low:  56085.0
# close:  56120.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  -20.0
# ##########################
# action:  2
#
# ********************
# COMPRADO:  56140.0
# VENDA:  56115.0
# LUCRO:  -25.0
# inicio:  09:28  termino:  09:31
# Duracao:  3.0
# recompensas:  [25.0, 35.0, -20.0]
# ********************
#
# ##########################
# Contador:  17
# Hora:  09:31
# Open:  56115.0
# High:  56130.0
# Low:  56060.0
# close:  56080.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  1
#
# ********************
# COMPRA:  56085.0
# ********************
#
# ##########################
# Contador:  18
# Hora:  09:32
# Open:  56085.0
# High:  56120.0
# Low:  56075.0
# close:  56095.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  10.0
# ##########################
# action:  2
#
# ********************
# COMPRADO:  56085.0
# VENDA:  56100.0
# LUCRO:  15.0
# inicio:  09:32  termino:  09:33
# Duracao:  1.0
# recompensas:  [10.0]
# ********************
#
# ##########################
# Contador:  19
# Hora:  09:33
# Open:  56100.0
# High:  56145.0
# Low:  56100.0
# close:  56140.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  0
# ##########################
# Contador:  20
# Hora:  09:34
# Open:  56130.0
# High:  56200.0
# Low:  56130.0
# close:  56180.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  0
# ##########################
# Contador:  21
# Hora:  09:35
# Open:  56180.0
# High:  56190.0
# Low:  56150.0
# close:  56155.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  1
#
# ********************
# COMPRA:  56150.0
# ********************
#
# ##########################
# Contador:  22
# Hora:  09:36
# Open:  56150.0
# High:  56160.0
# Low:  56110.0
# close:  56125.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  -25.0
# ##########################
# action:  2
#
# ********************
# COMPRADO:  56150.0
# VENDA:  56130.0
# LUCRO:  -20.0
# inicio:  09:36  termino:  09:37
# Duracao:  1.0
# recompensas:  [-25.0]
# ********************
#
# ##########################
# Contador:  23
# Hora:  09:37
# Open:  56130.0
# High:  56245.0
# Low:  56130.0
# close:  56155.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  0
# ##########################
# Contador:  24
# Hora:  09:38
# Open:  56160.0
# High:  56195.0
# Low:  56065.0
# close:  56105.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  2
#
# ********************
# VENDA:  56100.0
# ********************
#
# ##########################
# Contador:  25
# Hora:  09:39
# Open:  56100.0
# High:  56120.0
# Low:  56045.0
# close:  56070.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  30.0
# ##########################
# action:  1
#
# ********************
# VENDIDO:  56100.0
# COMPRA:  56080.0
# Lucro:  20.0
# inicio:  09:39  termino:  09:40
# Duracao:  1.0
# recompensas:  [30.0]
# ********************
#
# ##########################
# Contador:  26
# Hora:  09:40
# Open:  56080.0
# High:  56100.0
# Low:  56015.0
# close:  56020.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  1
#
# ********************
# COMPRA:  56020.0
# ********************
#
# ##########################
# Contador:  27
# Hora:  09:41
# Open:  56020.0
# High:  56060.0
# Low:  56020.0
# close:  56050.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  30.0
# ##########################
# action:  0
# ##########################
# Contador:  28
# Hora:  09:42
# Open:  56050.0
# High:  56060.0
# Low:  56030.0
# close:  56060.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  40.0
# ##########################
# action:  2
#
# ********************
# COMPRADO:  56020.0
# VENDA:  56055.0
# LUCRO:  35.0
# inicio:  09:41  termino:  09:43
# Duracao:  2.0
# recompensas:  [30.0, 40.0]
# ********************
#
# ##########################
# Contador:  29
# Hora:  09:43
# Open:  56055.0
# High:  56085.0
# Low:  56045.0
# close:  56055.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  0
# ##########################
# Contador:  30
# Hora:  09:44
# Open:  56050.0
# High:  56060.0
# Low:  56035.0
# close:  56050.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  1
#
# ********************
# COMPRA:  56035.0
# ********************
#
# ##########################
# Contador:  31
# Hora:  09:45
# Open:  56035.0
# High:  56035.0
# Low:  55995.0
# close:  56005.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  -30.0
# ##########################
# action:  1
# ##########################
# Contador:  32
# Hora:  09:46
# Open:  56005.0
# High:  56010.0
# Low:  55955.0
# close:  55990.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  -45.0
# ##########################
# action:  1
# ##########################
# Contador:  33
# Hora:  09:47
# Open:  55985.0
# High:  55995.0
# Low:  55930.0
# close:  55940.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  -95.0
# ##########################
# action:  2
#
# ********************
# COMPRADO:  56035.0
# VENDA:  55930.0
# LUCRO:  -105.0
# inicio:  09:45  termino:  09:48
# Duracao:  3.0
# recompensas:  [-30.0, -45.0, -95.0]
# ********************
#
# ##########################
# Contador:  34
# Hora:  09:48
# Open:  55930.0
# High:  56020.0
# Low:  55930.0
# close:  55990.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  2
#
# ********************
# VENDA:  56005.0
# ********************
#
# ##########################
# Contador:  35
# Hora:  09:49
# Open:  56005.0
# High:  56040.0
# Low:  55980.0
# close:  55995.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  10.0
# ##########################
# action:  1
#
# ********************
# VENDIDO:  56005.0
# COMPRA:  56005.0
# Lucro:  0.0
# inicio:  09:49  termino:  09:50
# Duracao:  1.0
# recompensas:  [10.0]
# ********************
#
# ##########################
# Contador:  36
# Hora:  09:50
# Open:  56005.0
# High:  56035.0
# Low:  55955.0
# close:  56020.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  2
#
# ********************
# VENDA:  56030.0
# ********************
#
# ##########################
# Contador:  37
# Hora:  09:51
# Open:  56030.0
# High:  56085.0
# Low:  56005.0
# close:  56055.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  -25.0
# ##########################
# action:  0
# ##########################
# Contador:  38
# Hora:  09:52
# Open:  56060.0
# High:  56065.0
# Low:  56035.0
# close:  56055.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  -25.0
# ##########################
# action:  1
#
# ********************
# VENDIDO:  56030.0
# COMPRA:  56050.0
# Lucro:  -20.0
# inicio:  09:51  termino:  09:53
# Duracao:  2.0
# recompensas:  [-25.0, -25.0]
# ********************
#
# ##########################
# Contador:  39
# Hora:  09:53
# Open:  56050.0
# High:  56060.0
# Low:  56030.0
# close:  56045.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  2
#
# ********************
# VENDA:  56050.0
# ********************
#
# ##########################
# Contador:  40
# Hora:  09:54
# Open:  56050.0
# High:  56075.0
# Low:  56035.0
# close:  56050.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  0.0
# ##########################
# action:  2
# ##########################
# Contador:  41
# Hora:  09:55
# Open:  56050.0
# High:  56065.0
# Low:  56050.0
# close:  56065.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  -15.0
# ##########################
# action:  1
#
# ********************
# VENDIDO:  56050.0
# COMPRA:  56060.0
# Lucro:  -10.0
# inicio:  09:54  termino:  09:56
# Duracao:  2.0
# recompensas:  [0.0, -15.0]
# ********************
#
# ##########################
# Contador:  42
# Hora:  09:56
# Open:  56060.0
# High:  56135.0
# Low:  56060.0
# close:  56080.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  0
# ##########################
# Contador:  43
# Hora:  09:57
# Open:  56070.0
# High:  56105.0
# Low:  56070.0
# close:  56090.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  1
#
# ********************
# COMPRA:  56090.0
# ********************
#
# ##########################
# Contador:  44
# Hora:  09:58
# Open:  56090.0
# High:  56115.0
# Low:  56085.0
# close:  56095.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  5.0
# ##########################
# action:  1
# ##########################
# Contador:  45
# Hora:  09:59
# Open:  56085.0
# High:  56130.0
# Low:  56080.0
# close:  56120.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  30.0
# ##########################
# action:  2
#
# ********************
# COMPRADO:  56090.0
# VENDA:  56130.0
# LUCRO:  40.0
# inicio:  09:58  termino:  10:00
# Duracao:  2.0
# recompensas:  [5.0, 30.0]
# ********************
#
# ##########################
# Contador:  46
# Hora:  10:00
# Open:  56130.0
# High:  56300.0
# Low:  56130.0
# close:  56215.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  0
# ##########################
# Contador:  47
# Hora:  10:01
# Open:  56215.0
# High:  56230.0
# Low:  56180.0
# close:  56195.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  1
#
# ********************
# COMPRA:  56185.0
# ********************
#
# ##########################
# Contador:  48
# Hora:  10:02
# Open:  56185.0
# High:  56200.0
# Low:  56145.0
# close:  56145.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  -40.0
# ##########################
# action:  2
#
# ********************
# COMPRADO:  56185.0
# VENDA:  56145.0
# LUCRO:  -40.0
# inicio:  10:02  termino:  10:03
# Duracao:  1.0
# recompensas:  [-40.0]
# ********************
#
# ##########################
# Contador:  49
# Hora:  10:03
# Open:  56145.0
# High:  56215.0
# Low:  56145.0
# close:  56180.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  2
#
# ********************
# VENDA:  56170.0
# ********************
#
# ##########################
# Contador:  50
# Hora:  10:04
# Open:  56170.0
# High:  56230.0
# Low:  56160.0
# close:  56205.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  -35.0
# ##########################
# action:  0
# ##########################
# Contador:  51
# Hora:  10:05
# Open:  56205.0
# High:  56210.0
# Low:  56155.0
# close:  56170.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  0.0
# ##########################
# action:  0
# ##########################
# Contador:  52
# Hora:  10:06
# Open:  56165.0
# High:  56250.0
# Low:  56155.0
# close:  56245.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  -75.0
# ##########################
# action:  0
# ##########################
# Contador:  53
# Hora:  10:07
# Open:  56235.0
# High:  56255.0
# Low:  56210.0
# close:  56225.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  -55.0
# ##########################
# action:  2
# ##########################
# Contador:  54
# Hora:  10:08
# Open:  56230.0
# High:  56255.0
# Low:  56155.0
# close:  56230.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  -60.0
# ##########################
# action:  1
#
# ********************
# VENDIDO:  56170.0
# COMPRA:  56230.0
# Lucro:  -60.0
# inicio:  10:04  termino:  10:09
# Duracao:  5.0
# recompensas:  [-35.0, 0.0, -75.0, -55.0, -60.0]
# ********************
#
# ##########################
# Contador:  55
# Hora:  10:09
# Open:  56230.0
# High:  56230.0
# Low:  56180.0
# close:  56230.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  2
#
# ********************
# VENDA:  56230.0
# ********************
#
# ##########################
# Contador:  56
# Hora:  10:10
# Open:  56230.0
# High:  56320.0
# Low:  56230.0
# close:  56270.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  -40.0
# ##########################
# action:  2
# ##########################
# Contador:  57
# Hora:  10:11
# Open:  56270.0
# High:  56270.0
# Low:  56190.0
# close:  56190.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  40.0
# ##########################
# action:  2
# ##########################
# Contador:  58
# Hora:  10:12
# Open:  56190.0
# High:  56210.0
# Low:  56100.0
# close:  56115.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  115.0
# ##########################
# action:  1
#
# ********************
# VENDIDO:  56230.0
# COMPRA:  56115.0
# Lucro:  115.0
# inicio:  10:10  termino:  10:13
# Duracao:  3.0
# recompensas:  [-40.0, 40.0, 115.0]
# ********************
#
# ##########################
# Contador:  59
# Hora:  10:13
# Open:  56115.0
# High:  56160.0
# Low:  56085.0
# close:  56100.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  0
# ##########################
# Contador:  60
# Hora:  10:14
# Open:  56100.0
# High:  56130.0
# Low:  56060.0
# close:  56060.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  1
#
# ********************
# COMPRA:  56055.0
# ********************
#
# ##########################
# Contador:  61
# Hora:  10:15
# Open:  56055.0
# High:  56070.0
# Low:  55985.0
# close:  56025.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  -30.0
# ##########################
# action:  1
# ##########################
# Contador:  62
# Hora:  10:16
# Open:  56030.0
# High:  56070.0
# Low:  55955.0
# close:  55965.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  -90.0
# ##########################
# action:  2
#
# ********************
# COMPRADO:  56055.0
# VENDA:  55965.0
# LUCRO:  -90.0
# inicio:  10:15  termino:  10:17
# Duracao:  2.0
# recompensas:  [-30.0, -90.0]
# ********************
#
# ##########################
# Contador:  63
# Hora:  10:17
# Open:  55965.0
# High:  56025.0
# Low:  55940.0
# close:  56025.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  2
#
# ********************
# VENDA:  56025.0
# ********************
#
# ##########################
# Contador:  64
# Hora:  10:18
# Open:  56025.0
# High:  56040.0
# Low:  55980.0
# close:  56000.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  25.0
# ##########################
# action:  1
#
# ********************
# VENDIDO:  56025.0
# COMPRA:  56000.0
# Lucro:  25.0
# inicio:  10:18  termino:  10:19
# Duracao:  1.0
# recompensas:  [25.0]
# ********************
#
# ##########################
# Contador:  65
# Hora:  10:19
# Open:  56000.0
# High:  56080.0
# Low:  56000.0
# close:  56070.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  1
#
# ********************
# COMPRA:  56075.0
# ********************
#
# ##########################
# Contador:  66
# Hora:  10:20
# Open:  56075.0
# High:  56120.0
# Low:  56050.0
# close:  56110.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  35.0
# ##########################
# action:  2
#
# ********************
# COMPRADO:  56075.0
# VENDA:  56120.0
# LUCRO:  45.0
# inicio:  10:20  termino:  10:21
# Duracao:  1.0
# recompensas:  [35.0]
# ********************
#
# ##########################
# Contador:  67
# Hora:  10:21
# Open:  56120.0
# High:  56130.0
# Low:  56085.0
# close:  56105.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  0
# ##########################
# Contador:  68
# Hora:  10:22
# Open:  56105.0
# High:  56135.0
# Low:  56100.0
# close:  56105.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  0
# ##########################
# Contador:  69
# Hora:  10:23
# Open:  56100.0
# High:  56135.0
# Low:  56055.0
# close:  56060.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  1
#
# ********************
# COMPRA:  56065.0
# ********************
#
# ##########################
# Contador:  70
# Hora:  10:24
# Open:  56065.0
# High:  56070.0
# Low:  56010.0
# close:  56030.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  -35.0
# ##########################
# action:  0
# ##########################
# Contador:  71
# Hora:  10:25
# Open:  56030.0
# High:  56040.0
# Low:  56005.0
# close:  56030.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  -35.0
# ##########################
# action:  1
# ##########################
# Contador:  72
# Hora:  10:26
# Open:  56020.0
# High:  56125.0
# Low:  56000.0
# close:  56110.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  45.0
# ##########################
# action:  0
# ##########################
# Contador:  73
# Hora:  10:27
# Open:  56100.0
# High:  56180.0
# Low:  56085.0
# close:  56145.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  80.0
# ##########################
# action:  1
# ##########################
# Contador:  74
# Hora:  10:28
# Open:  56140.0
# High:  56240.0
# Low:  56130.0
# close:  56235.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  170.0
# ##########################
# action:  2
#
# ********************
# COMPRADO:  56065.0
# VENDA:  56240.0
# LUCRO:  175.0
# inicio:  10:24  termino:  10:29
# Duracao:  5.0
# recompensas:  [-35.0, -35.0, 45.0, 80.0, 170.0]
# ********************
#
# ##########################
# Contador:  75
# Hora:  10:29
# Open:  56240.0
# High:  56295.0
# Low:  56200.0
# close:  56285.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  0
# ##########################
# Contador:  76
# Hora:  10:30
# Open:  56275.0
# High:  56290.0
# Low:  56160.0
# close:  56215.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  1
#
# ********************
# COMPRA:  56200.0
# ********************
#
# ##########################
# Contador:  77
# Hora:  10:31
# Open:  56200.0
# High:  56225.0
# Low:  56140.0
# close:  56170.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  -30.0
# ##########################
# action:  1
# ##########################
# Contador:  78
# Hora:  10:32
# Open:  56170.0
# High:  56190.0
# Low:  56150.0
# close:  56165.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  -35.0
# ##########################
# action:  0
# ##########################
# Contador:  79
# Hora:  10:33
# Open:  56165.0
# High:  56210.0
# Low:  56165.0
# close:  56200.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  0.0
# ##########################
# action:  2
#
# ********************
# COMPRADO:  56200.0
# VENDA:  56190.0
# LUCRO:  -10.0
# inicio:  10:31  termino:  10:34
# Duracao:  3.0
# recompensas:  [-30.0, -35.0, -0.0]
# ********************
#
# ##########################
# Contador:  80
# Hora:  10:34
# Open:  56190.0
# High:  56205.0
# Low:  56110.0
# close:  56125.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  1
#
# ********************
# COMPRA:  56125.0
# ********************
#
# ##########################
# Contador:  81
# Hora:  10:35
# Open:  56125.0
# High:  56215.0
# Low:  56090.0
# close:  56175.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  50.0
# ##########################
# action:  2
#
# ********************
# COMPRADO:  56125.0
# VENDA:  56180.0
# LUCRO:  55.0
# inicio:  10:35  termino:  10:36
# Duracao:  1.0
# recompensas:  [50.0]
# ********************
#
# ##########################
# Contador:  82
# Hora:  10:36
# Open:  56180.0
# High:  56210.0
# Low:  56155.0
# close:  56180.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  1
#
# ********************
# COMPRA:  56180.0
# ********************
#
# ##########################
# Contador:  83
# Hora:  10:37
# Open:  56180.0
# High:  56230.0
# Low:  56160.0
# close:  56200.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  20.0
# ##########################
# action:  0
# ##########################
# Contador:  84
# Hora:  10:38
# Open:  56195.0
# High:  56195.0
# Low:  56145.0
# close:  56170.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  -10.0
# ##########################
# action:  2
#
# ********************
# COMPRADO:  56180.0
# VENDA:  56165.0
# LUCRO:  -15.0
# inicio:  10:37  termino:  10:39
# Duracao:  2.0
# recompensas:  [20.0, -10.0]
# ********************
#
# ##########################
# Contador:  85
# Hora:  10:39
# Open:  56165.0
# High:  56165.0
# Low:  56105.0
# close:  56120.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  1
#
# ********************
# COMPRA:  56115.0
# ********************
#
# ##########################
# Contador:  86
# Hora:  10:40
# Open:  56115.0
# High:  56125.0
# Low:  56105.0
# close:  56115.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  0.0
# ##########################
# action:  1
# ##########################
# Contador:  87
# Hora:  10:41
# Open:  56115.0
# High:  56120.0
# Low:  56065.0
# close:  56120.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  5.0
# ##########################
# action:  2
#
# ********************
# COMPRADO:  56115.0
# VENDA:  56125.0
# LUCRO:  10.0
# inicio:  10:40  termino:  10:42
# Duracao:  2.0
# recompensas:  [-0.0, 5.0]
# ********************
#
# ##########################
# Contador:  88
# Hora:  10:42
# Open:  56125.0
# High:  56170.0
# Low:  56075.0
# close:  56085.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  2
#
# ********************
# VENDA:  56090.0
# ********************
#
# ##########################
# Contador:  89
# Hora:  10:43
# Open:  56090.0
# High:  56125.0
# Low:  56075.0
# close:  56120.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  -30.0
# ##########################
# action:  1
#
# ********************
# VENDIDO:  56090.0
# COMPRA:  56125.0
# Lucro:  -35.0
# inicio:  10:43  termino:  10:44
# Duracao:  1.0
# recompensas:  [-30.0]
# ********************
#
# ##########################
# Contador:  90
# Hora:  10:44
# Open:  56125.0
# High:  56140.0
# Low:  56040.0
# close:  56075.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  0
# ##########################
# Contador:  91
# Hora:  10:45
# Open:  56070.0
# High:  56070.0
# Low:  56015.0
# close:  56045.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  2
#
# ********************
# VENDA:  56035.0
# ********************
#
# ##########################
# Contador:  92
# Hora:  10:46
# Open:  56035.0
# High:  56070.0
# Low:  55950.0
# close:  55960.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  True
# recompensa:  75.0
# ##########################
# action:  0
#
# ********************
# VENDIDO:  56035.0
# COMPRA:  55835.0
# Lucro:  200.0
# inicio:  10:46  termino:  10:47
# Duracao:  1.0
# recompensas:  [75.0, 370.0]
# ********************
#
# ##########################
# Contador:  93
# Hora:  10:47
# Open:  55960.0
# High:  55960.0
# Low:  55655.0
# close:  55665.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  200
# ##########################
# action:  1
#
# ********************
# COMPRA:  55670.0
# ********************
#
# ##########################
# Contador:  94
# Hora:  10:48
# Open:  55670.0
# High:  55825.0
# Low:  55660.0
# close:  55815.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  145.0
# ##########################
# action:  2
#
# ********************
# COMPRADO:  55670.0
# VENDA:  55815.0
# LUCRO:  145.0
# inicio:  10:48  termino:  10:49
# Duracao:  1.0
# recompensas:  [145.0]
# ********************
#
# ##########################
# Contador:  95
# Hora:  10:49
# Open:  55815.0
# High:  55820.0
# Low:  55700.0
# close:  55805.0
# acao:  2
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  0
# ##########################
# Contador:  96
# Hora:  10:50
# Open:  55810.0
# High:  55840.0
# Low:  55755.0
# close:  55795.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  0
# ##########################
# Contador:  97
# Hora:  10:51
# Open:  55785.0
# High:  55855.0
# Low:  55780.0
# close:  55850.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  False
# Vendido:  False
# recompensa:  0
# ##########################
# action:  1
#
# ********************
# COMPRA:  55850.0
# ********************
#
# ##########################
# Contador:  98
# Hora:  10:52
# Open:  55850.0
# High:  55910.0
# Low:  55835.0
# close:  55875.0
# acao:  1
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  25.0
# ##########################
# action:  0
# ##########################
# Contador:  99
# Hora:  10:53
# Open:  55880.0
# High:  55900.0
# Low:  55850.0
# close:  55870.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  20.0
# ##########################
# action:  0
# ##########################
# Contador:  100
# Hora:  10:54
# Open:  55860.0
# High:  55885.0
# Low:  55760.0
# close:  55850.0
# acao:  0
# stop:  -200
# gain:  200
# Comprado:  True
# Vendido:  False
# recompensa:  0.0
# ##########################

# %%
gain
# Out:
# 200
